# %% [markdown]
# # Marcel's Holidays Preferences

# %% [markdown]
# ## Table of Content
#
# 1. [Name](#markdown-header-name)
# 2. [Marcel's Photo](#markdown-header-photo-of-marcel)
# 3. [Photo of the holiday destination](#markdown-header-photo-of-the-holiday-destination)
# 4. [Top 3 Reasons](#markdown-header-top-3-reasons)

# %% [markdown]
# This notebook aims to introduce my **hoidays preferences**.

# %% [markdown]
# ## Name

# %%
input('Enter your name: ')
# Out:
# Enter your name: Marcel
# 'Marcel'

# %% [markdown]
# ## Photo of Marcel
# ![Marcel.png](attachment:Marcel.png)

# %% [markdown]
# ## Photo of the Holiday Destination
# ### __[Neuschwanstein Castle](https://www.youtube.com/watch?v=zdo6SQvlwe8)__
# ![Neuschwanstein%20Castle.jpeg](attachment:Neuschwanstein%20Castle.jpeg)

# %% [markdown]
# ## Top 3 Reasons
# - **Iconic image** of Germany
# - Rich **history**
# - **Inspiration** for *Disney* catsle
